# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\user\Desktop\ML\archive\Raisin_Dataset.csv")

# %%
df.sample(3)
# Out:
#        Area  MajorAxisLength  MinorAxisLength  Eccentricity  ConvexArea  \
# 774   76624       473.965993       207.736989      0.898831       80356
# 467  184784       740.108710       320.587830      0.901316      192699
# 383   66797       358.198918       240.782694      0.740366       68732
#
#        Extent  Perimeter    Class
# 774  0.661008   1205.819    Besni
# 467  0.645353   1791.568    Besni
# 383  0.697663   1006.375  Kecimen

# %%
df.isna().sum()
# Out:
# Area               0
# MajorAxisLength    0
# MinorAxisLength    0
# Eccentricity       0
# ConvexArea         0
# Extent             0
# Perimeter          0
# Class              0
# dtype: int64

# %%
df.Class.value_counts()
# Out:
# Class
# Kecimen    450
# Besni      450
# Name: count, dtype: int64

# %%
df["Class"]=df["Class"].map({
    "Kecimen":1,
    "Besni":0
})
df
# Out:
#       Area  MajorAxisLength  MinorAxisLength  Eccentricity  ConvexArea  \
# 0    87524       442.246011       253.291155      0.819738       90546
# 1    75166       406.690687       243.032436      0.801805       78789
# 2    90856       442.267048       266.328318      0.798354       93717
# 3    45928       286.540559       208.760042      0.684989       47336
# 4    79408       352.190770       290.827533      0.564011       81463
# ..     ...              ...              ...           ...         ...
# 895  83248       430.077308       247.838695      0.817263       85839
# 896  87350       440.735698       259.293149      0.808629       90899
# 897  99657       431.706981       298.837323      0.721684      106264
# 898  93523       476.344094       254.176054      0.845739       97653
# 899  85609       512.081774       215.271976      0.907345       89197
#
#        Extent  Perimeter  Class
# 0    0.758651   1184.040      1
# 1    0.684130   1121.786      1
# 2    0.637613   1208.575      1
# 3    0.699599    844.162      1
# 4    0.792772   1073.251      1
# ..        ...        ...    ...
# 895  0.668793   1129.072      0
# 896  0.636476   1214.252      0
# 897  0.741099   1292.828      0
# 898  0.658798   1258.548      0
# 899  0.632020   1272.862      0
#
# [900 rows x 8 columns]

# %%
x=df.drop(columns=["Class"])
y=df.Class

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(
    x,
    y,
    random_state=45,
    test_size=0.1
)

# %%
from sklearn.ensemble import RandomForestClassifier
model=RandomForestClassifier(
    n_estimators =10,
    criterion ="gini",
    max_depth=100,
    random_state=42
)

# %%
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier(max_depth=100, n_estimators=10, random_state=42)

# %%
y_pred=model.predict(x_test)

# %%
model.score(x_train,y_train)
# Out:
# 0.9888888888888889

# %%
model.score(x_test,y_test)
# Out:
# 0.8777777777777778

# %%
from sklearn.metrics import classification_report
report = classification_report(
    y_test,
    y_pred,
)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.88      0.89        51
#            1       0.85      0.87      0.86        39
#
#     accuracy                           0.88        90
#    macro avg       0.88      0.88      0.88        90
# weighted avg       0.88      0.88      0.88        90

# %%
import pickle

# %%
with open("RF.pkl", "wb") as file:
    pickle.dump(model, file)

# %%
test_data=dict(zip(x_train.columns,
              round(x_test.iloc[3])))
test_data
# Out:
# {'Area': 59654.0,
#  'MajorAxisLength': 351.0,
#  'MinorAxisLength': 219.0,
#  'Eccentricity': 1.0,
#  'ConvexArea': 62384.0,
#  'Extent': 1.0,
#  'Perimeter': 980.0}
